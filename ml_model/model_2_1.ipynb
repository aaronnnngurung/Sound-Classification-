# %% [markdown]
# ## SECTION 1 — Imports

# %%
import os
import glob
import random

import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
from scipy.signal import butter, sosfiltfilt

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## SECTION 2 — Constants

# %%
# -----------------------------
# Dataset paths
# -----------------------------
AUDIO_DIR = "../ESC-50-master/audio/"
CSV_PATH = "../ESC-50-master/meta/esc50.csv"
REAL_MIC_DIR = "../ESC-50-master/real_mic_data/"

# -----------------------------
# Audio processing parameters
# MUST match the Flutter app exactly. DO NOT CHANGE.
# -----------------------------
SR = 22050
DURATION = 5
N_MELS = 64
MAX_PAD_LEN = 216
N_FFT = 2048
HOP_LENGTH = 512
TOP_DB = 80

# -----------------------------
# Class definitions
# -----------------------------
# The six emergency sounds the app must actively alert the user about.
EMERGENCY_CLASSES = [
    "siren",
    "crying_baby",
    "door_wood_knock",
    "glass_breaking",
    "fireworks",
    "car_horn",
]

# Common everyday / ambient ESC-50 sounds. Kept defined (but unused for now)
# so they're one flag-flip away from being brought back in — see
# INCLUDE_NEGATIVE_CLASSES below. These exist so the model would have
# somewhere legitimate to send non-emergency audio instead of being forced
# to pick an emergency label every single time (this is what was causing
# things like "Fireworks 100%" on silence/background noise). Revisit once
# the emergency-only model's real-mic behavior (e.g. fireworks overfitting)
# has been checked out.
NEGATIVE_CLASSES = [
    "keyboard_typing",
    "footsteps",
    "clock_tick",
    "mouse_click",
    "rain",
    "wind",
    "breathing",
    "chirping_birds",
    "washing_machine",
    "laughing",
]

# -----------------------------
# Toggle: are negative/ambient classes included in training?
# -----------------------------
# For now we're going back to training on emergency sounds only, and
# evaluating against real microphone recordings. Flip this to True later
# once the emergency-only model has been checked for issues (e.g. fireworks
# overfitting) and negative classes are ready to be reintroduced.
INCLUDE_NEGATIVE_CLASSES = False

# Every class the model will be trained to output.
# Order matters: this order defines the label indices, the CNN's output
# layer, and the labels.txt exported for the Flutter app.
ALL_CLASSES = EMERGENCY_CLASSES + (NEGATIVE_CLASSES if INCLUDE_NEGATIVE_CLASSES else [])

NUM_CLASSES = len(ALL_CLASSES)

LABEL_MAP = {category: idx for idx, category in enumerate(ALL_CLASSES)}
INVERSE_LABEL_MAP = {idx: category for category, idx in LABEL_MAP.items()}

# Convenience sets used later for the emergency-vs-non-emergency rollup
EMERGENCY_LABEL_IDS = {LABEL_MAP[c] for c in EMERGENCY_CLASSES if c in LABEL_MAP}
NEGATIVE_LABEL_IDS = {LABEL_MAP[c] for c in NEGATIVE_CLASSES if c in LABEL_MAP}

print(f"Emergency classes ({len(EMERGENCY_CLASSES)}): {EMERGENCY_CLASSES}")
print(f"Negative classes included: {INCLUDE_NEGATIVE_CLASSES}")
print(f"Total classes ({NUM_CLASSES}): {ALL_CLASSES}")
# Out:
# Emergency classes (6): ['siren', 'crying_baby', 'door_wood_knock', 'glass_breaking', 'fireworks', 'car_horn']
# Negative classes included: False
# Total classes (6): ['siren', 'crying_baby', 'door_wood_knock', 'glass_breaking', 'fireworks', 'car_horn']

# %% [markdown]
# ## SECTION 3 — Audio Processing
#
# Unchanged from the original pipeline — these parameters must stay pixel-for-pixel identical to what the Flutter app recreates.

# %%
def process_audio_to_mel(audio, sr,
                         n_mels=N_MELS,
                         max_pad_len=MAX_PAD_LEN):

    # Ensure exactly 5 seconds
    target_length = SR * DURATION

    if len(audio) < target_length:
        audio = np.pad(audio, (0, target_length - len(audio)))
    else:
        audio = audio[:target_length]

    # Compute mel spectrogram
    mel_spec = librosa.feature.melspectrogram(
        y=audio,
        sr=sr,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        n_mels=n_mels,
        power=2.0,
    )

    # Convert to dB
    mel_spec_db = librosa.power_to_db(
        mel_spec,
        ref=np.max,
        top_db=TOP_DB,
    )

    # Pad or trim to MAX_PAD_LEN frames
    if mel_spec_db.shape[1] < max_pad_len:
        pad = max_pad_len - mel_spec_db.shape[1]
        mel_spec_db = np.pad(
            mel_spec_db,
            ((0, 0), (0, pad)),
            mode="constant",
        )
    else:
        mel_spec_db = mel_spec_db[:, :max_pad_len]

    # Standardize each spectrogram
    mean = np.mean(mel_spec_db)
    std = np.std(mel_spec_db)

    mel_spec_db = (mel_spec_db - mean) / (std + 1e-6)

    return mel_spec_db.astype(np.float32)

# %% [markdown]
# ## SECTION 4 — Data Augmentation
#
# Two layers of augmentation, both applied only to the training split (see Section 8), never to validation or real-mic data:
#
# 1. **Waveform-level** — 10 independent techniques (up from 5). `augment_audio` now guarantees at least 2 stack per copy, so augmented samples don't collapse back toward near-duplicates of the original even when generating many copies per clip.
# 2. **Spectrogram-level (SpecAugment)** — frequency/time masking applied *after* `process_audio_to_mel`, in Section 8. This is effectively free extra diversity since it doesn't require re-decoding or re-transforming audio.

# %%
from scipy.signal import butter, sosfiltfilt, iirpeak, fftconvolve

# ------------------------------------------------------------------
# Waveform-level augmentations
# ------------------------------------------------------------------

# Add white noise
def add_noise(data):
    noise_factor = random.uniform(0.001, 0.008)
    noise = np.random.randn(len(data))
    augmented = data + noise_factor * noise
    return np.clip(augmented, -1.0, 1.0)

# Add pink-ish noise (low-frequency-weighted)
def add_pink_noise(data):
    noise_factor = random.uniform(0.001, 0.006)
    white = np.random.randn(len(data))
    pink = np.cumsum(white)
    pink = pink / (np.max(np.abs(pink)) + 1e-9)
    augmented = data + noise_factor * pink
    return np.clip(augmented, -1.0, 1.0)

# Random pitch shift
def pitch_shift(data, sr):
    steps = random.uniform(-2, 2)
    return librosa.effects.pitch_shift(
        y=data,
        sr=sr,
        n_steps=steps,
    )

# Random speed change
def time_stretch(data):
    rate = random.uniform(0.90, 1.10)
    stretched = librosa.effects.time_stretch(
        data,
        rate=rate,
    )
    if len(stretched) > len(data):
        stretched = stretched[:len(data)]
    else:
        stretched = np.pad(
            stretched,
            (0, len(data) - len(stretched)),
        )
    return stretched

# Random volume
def random_gain(data):
    gain = random.uniform(0.8, 1.2)
    augmented = data * gain
    return np.clip(augmented, -1.0, 1.0)

# Random time shift
def time_shift(data):
    shift = random.randint(
        -int(0.15 * len(data)),
        int(0.15 * len(data)),
    )
    return np.roll(data, shift)

# Flip waveform polarity
def polarity_invert(data):
    return -data

# Random band-pass filter
def bandpass_filter(data, sr):
    low = random.uniform(50, 300)
    high = random.uniform(4000, min(8000.0, sr / 2 - 100))
    sos = butter(4, [low, high], btype="bandpass", fs=sr, output="sos")
    return sosfiltfilt(sos, data).astype(np.float32)

# Fade in/out envelope
def fade_in_out(data):
    length = len(data)
    fade_len = max(1, int(length * random.uniform(0.05, 0.2)))
    envelope = np.ones(length)
    envelope[:fade_len] = np.linspace(0, 1, fade_len)
    envelope[-fade_len:] = np.linspace(1, 0, fade_len)
    return data * envelope

# Randomly silence a short waveform segment
def random_silence_gap(data):
    length = len(data)
    gap_len = max(1, int(length * random.uniform(0.02, 0.08)))
    start = random.randint(0, length - gap_len)
    augmented = np.copy(data)
    augmented[start:start + gap_len] = 0.0
    return augmented

# ------------------------------------------------------------------
# "Real phone microphone" channel simulators
# ------------------------------------------------------------------

# Synthetic room reverb
def add_reverb(data, sr):
    decay = random.uniform(0.15, 0.6)
    wet_mix = random.uniform(0.15, 0.45)
    n_ir = max(1, int(sr * decay))
    t = np.arange(n_ir) / sr
    ir = np.random.randn(n_ir) * np.exp(-t / (decay / 4))
    ir = ir / (np.max(np.abs(ir)) + 1e-9)
    wet = fftconvolve(data, ir, mode="full")[:len(data)]
    wet = wet / (np.max(np.abs(wet)) + 1e-9) * (np.max(np.abs(data)) + 1e-9)
    augmented = (1 - wet_mix) * data + wet_mix * wet
    return np.clip(augmented, -1.0, 1.0).astype(np.float32)

# Random phone-mic frequency coloring
def mic_coloring_filter(data, sr):
    center_freq = random.uniform(800, 4000)
    q = random.uniform(1.0, 4.0)
    gain_db = random.uniform(-6, 6)
    b, a = iirpeak(center_freq, q, fs=sr)
    colored = sosfiltfilt(np.array([[b[0], b[1], b[2], a[0], a[1], a[2]]]), data)
    mix = np.clip(abs(gain_db) / 6.0, 0.0, 1.0)
    if gain_db >= 0:
        augmented = data + mix * (colored - data)
    else:
        augmented = data - mix * (colored - data)

    cutoff = random.uniform(6000, min(9500.0, sr / 2 - 100))
    sos = butter(2, cutoff, btype="lowpass", fs=sr, output="sos")
    augmented = sosfiltfilt(sos, augmented)
    return np.clip(augmented, -1.0, 1.0).astype(np.float32)

# Simulate lossy codec / low-bitrate transmission artifacts
def codec_compression_artifact(data, sr):
    bit_depth = random.choice([6, 7, 8])
    levels = 2 ** bit_depth
    quantized = np.round(data * levels) / levels
    cutoff = random.uniform(5000, min(8000.0, sr / 2 - 100))
    sos = butter(3, cutoff, btype="lowpass", fs=sr, output="sos")
    augmented = sosfiltfilt(sos, quantized)
    return np.clip(augmented, -1.0, 1.0).astype(np.float32)

# Simulate dynamic range compressor
def dynamic_range_compress(data):
    drive = random.uniform(1.5, 4.0)
    compressed = np.tanh(data * drive) / np.tanh(drive)
    return np.clip(compressed, -1.0, 1.0).astype(np.float32)

# Waveform augmentations
_WAVEFORM_AUGMENTATIONS = [
    lambda a, sr: add_noise(a),
    lambda a, sr: add_pink_noise(a),
    lambda a, sr: pitch_shift(a, sr),
    lambda a, sr: time_stretch(a),
    lambda a, sr: random_gain(a),
    lambda a, sr: time_shift(a),
    lambda a, sr: polarity_invert(a),
    lambda a, sr: fade_in_out(a),
    lambda a, sr: random_silence_gap(a),
]

# Channel simulators
_CHANNEL_AUGMENTATIONS = [
    lambda a, sr: bandpass_filter(a, sr),
    lambda a, sr: add_reverb(a, sr),
    lambda a, sr: mic_coloring_filter(a, sr),
    lambda a, sr: codec_compression_artifact(a, sr),
    lambda a, sr: dynamic_range_compress(a),
]

# Random augmentation pipeline
def augment_audio(data, sr, apply_prob=0.4, min_ops=2, channel_prob=0.6):
    audio = np.copy(data)
    applied = 0
    order = list(_WAVEFORM_AUGMENTATIONS)
    random.shuffle(order)
    for fn in order:
        if random.random() < apply_prob:
            audio = fn(audio, sr)
            applied += 1
    if applied < min_ops:
        for fn in random.sample(order, min_ops - applied):
            audio = fn(audio, sr)

    channel_order = list(_CHANNEL_AUGMENTATIONS)
    random.shuffle(channel_order)
    channel_applied = 0
    for fn in channel_order:
        if channel_applied == 0 or random.random() < channel_prob:
            audio = fn(audio, sr)
            channel_applied += 1
    return audio

# ------------------------------------------------------------------
# Spectrogram-level augmentation (SpecAugment)
# ------------------------------------------------------------------
def spec_freq_mask(mel_db, num_masks=1, max_width=8):
    mel_db = mel_db.copy()
    n_mels = mel_db.shape[0]
    fill_value = mel_db.min()
    for _ in range(num_masks):
        width = random.randint(1, max_width)
        start = random.randint(0, max(0, n_mels - width))
        mel_db[start:start + width, :] = fill_value
    return mel_db

def spec_time_mask(mel_db, num_masks=1, max_width=16):
    mel_db = mel_db.copy()
    n_frames = mel_db.shape[1]
    fill_value = mel_db.min()
    for _ in range(num_masks):
        width = random.randint(1, max_width)
        start = random.randint(0, max(0, n_frames - width))
        mel_db[:, start:start + width] = fill_value
    return mel_db

def apply_spec_augment(mel_db, prob=0.5):
    if random.random() < prob:
        mel_db = spec_freq_mask(mel_db)
    if random.random() < prob:
        mel_db = spec_time_mask(mel_db)
    return mel_db

# %% [markdown]
# ## SECTION 5 — Load ESC-50
#
# Loads **only** `ALL_CLASSES` (emergency + negative) from ESC-50. This is the key change from the original notebook, which only ever loaded the 6 emergency classes.

# %%
print("Loading ESC-50 clips...")
raw_clips = []

df = pd.read_csv(CSV_PATH)
df_filtered = df[df["category"].isin(ALL_CLASSES)].reset_index(drop=True)

missing_classes = set(ALL_CLASSES) - set(df_filtered["category"].unique())
if missing_classes:
    print(f"WARNING: these classes were not found in {CSV_PATH}: {missing_classes}")

for _, row in df_filtered.iterrows():
    path = os.path.join(AUDIO_DIR, row["filename"])
    try:
        audio, sr = librosa.load(path, sr=SR, res_type="kaiser_fast")
        label = LABEL_MAP[row["category"]]
        raw_clips.append((audio, sr, label))
    except Exception as e:
        print(f"Warning: {path} - {e}")

print(f"Loaded {len(raw_clips)} ESC-50 clips across {len(ALL_CLASSES)} classes")

# Per-class counts, useful to catch missing/short categories early
counts = pd.Series([INVERSE_LABEL_MAP[c[2]] for c in raw_clips]).value_counts()
print("\nPer-class clip counts:")
print(counts.reindex(ALL_CLASSES))
# Out:
# Loading ESC-50 clips...
# c:\Users\ACER\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\ACER\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\Users\ACER\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# Loaded 240 ESC-50 clips across 6 classes
#
# Per-class clip counts:
# siren              40
# crying_baby        40
# door_wood_knock    40
# glass_breaking     40
# fireworks          40
# car_horn           40
# Name: count, dtype: int64

# %% [markdown]
# ## SECTION 6 — Load Real Microphone Dataset
#
# These recordings are **never** used for training or validation — held out purely for final, real-world evaluation (Section 13). Only folders that actually exist under `REAL_MIC_DIR` are loaded, so this works whether you only have recordings for the emergency classes or have also started collecting negative-class recordings.

# %%
print("\nLoading real microphone clips (held-out evaluation set only)...")
real_test_clips = []

for category in ALL_CLASSES:
    class_dir = os.path.join(REAL_MIC_DIR, category)
    if not os.path.isdir(class_dir):
        continue  # no real-mic recordings collected for this class yet

    files = glob.glob(os.path.join(class_dir, "*"))
    for path in files:
        try:
            audio, sr = librosa.load(path, sr=SR, res_type="kaiser_fast")
            target_len = SR * DURATION
            if len(audio) < target_len:
                audio = np.pad(audio, (0, target_len - len(audio)))
            else:
                audio = audio[:target_len]
            real_test_clips.append((audio, sr, LABEL_MAP[category]))
        except Exception as e:
            print(f"Warning: {path} - {e}")

print(f"Loaded {len(real_test_clips)} real microphone clips for evaluation")

if real_test_clips:
    real_counts = pd.Series([INVERSE_LABEL_MAP[c[2]] for c in real_test_clips]).value_counts()
    print("\nPer-class real-mic clip counts:")
    print(real_counts)
else:
    print("No real microphone recordings found under REAL_MIC_DIR.")
# Out:
# Loading real microphone clips (held-out evaluation set only)...
# Loaded 30 real microphone clips for evaluation
#
# Per-class real-mic clip counts:
# siren              5
# crying_baby        5
# door_wood_knock    5
# glass_breaking     5
# fireworks          5
# car_horn           5
# Name: count, dtype: int64

# %% [markdown]
# ## SECTION 7 — Train / Validation Split
#
# Stratified split on ESC-50 clips only. Real microphone recordings are never part of this split.

# %%
labels_only = [c[2] for c in raw_clips]

train_idx, val_idx = train_test_split(
    range(len(raw_clips)),
    test_size=0.2,
    random_state=SEED,
    stratify=labels_only,
)

train_raw = [raw_clips[i] for i in train_idx]
val_raw = [raw_clips[i] for i in val_idx]

print(f"ESC-50 split: Train {len(train_raw)} | Val {len(val_raw)}")
# Out:
# ESC-50 split: Train 192 | Val 48

# %% [markdown]
# ## SECTION 8 — Build Dataset
#
# Augmentation is applied **only** to the training set. Validation and real-mic data are processed with `process_audio_to_mel` alone — never augmented.
#
# `AUGMENT_TIMES` controls how many augmented copies are generated per original training clip (raised from 6 to 14, so the training set is now ~15x the raw clip count instead of ~7x). Since Section 4 now has 10 waveform techniques plus SpecAugment masking to draw from, the extra copies stay meaningfully different from each other instead of being near-duplicates. This will make training noticeably slower — lower `AUGMENT_TIMES` if that becomes a problem.

# %%
# Number of augmented copies generated per original training clip.
# Total training-set multiplier = 1 (original) + AUGMENT_TIMES.
AUGMENT_TIMES = 14


def build_augmented_set(raw_set, augment=False, augment_times=AUGMENT_TIMES, use_spec_augment=True):

    X = []
    y = []

    for audio, sr, label in raw_set:

        # Always include the original, unaugmented clip
        X.append(process_audio_to_mel(audio, sr))
        y.append(label)

        if augment:
            for _ in range(augment_times):
                augmented_audio = augment_audio(audio, sr)
                mel_db = process_audio_to_mel(augmented_audio, sr)
                if use_spec_augment:
                    mel_db = apply_spec_augment(mel_db)
                X.append(mel_db)
                y.append(label)

    X = np.array(X, dtype=np.float32)
    y = np.array(y)

    return X, y


print("Building training set (augmented)...")
X_train, y_train = build_augmented_set(
    train_raw,
    augment=True,
    augment_times=AUGMENT_TIMES,
    use_spec_augment=True,
)

print("Building validation set (no augmentation)...")
X_val, y_val = build_augmented_set(
    val_raw,
    augment=False,
)

print("Building real-world evaluation set (no augmentation)...")
X_real_test, y_real_test = build_augmented_set(
    real_test_clips,
    augment=False,
)

X_train = X_train.reshape(-1, X_train.shape[1], X_train.shape[2], 1)
X_val = X_val.reshape(-1, X_val.shape[1], X_val.shape[2], 1)
if len(X_real_test) > 0:
    X_real_test = X_real_test.reshape(-1, X_real_test.shape[1], X_real_test.shape[2], 1)

print(f"\nTrain shape: {X_train.shape}")
print(f"Val shape: {X_val.shape}")
print(f"Real-world eval shape: {X_real_test.shape}")
# Out:
# Building training set (augmented)...
# Building validation set (no augmentation)...
# Building real-world evaluation set (no augmentation)...
#
# Train shape: (2880, 64, 216, 1)
# Val shape: (48, 64, 216, 1)
# Real-world eval shape: (30, 64, 216, 1)

# %% [markdown]
# ## SECTION 9 — Verify Preprocessing
#
# Sanity checks before spending time training: correct tensor shape for the Flutter model input `(64, 216, 1)`, no NaN/Inf values, sensible value ranges, class balance across splits, and a visual check of a spectrogram.

# %%
expected_shape = (N_MELS, MAX_PAD_LEN, 1)

assert X_train.shape[1:] == expected_shape, f"Train shape mismatch: {X_train.shape[1:]} != {expected_shape}"
assert X_val.shape[1:] == expected_shape, f"Val shape mismatch: {X_val.shape[1:]} != {expected_shape}"
if len(X_real_test) > 0:
    assert X_real_test.shape[1:] == expected_shape, f"Real-mic shape mismatch: {X_real_test.shape[1:]} != {expected_shape}"

for name, arr in [("X_train", X_train), ("X_val", X_val), ("X_real_test", X_real_test)]:
    if len(arr) == 0:
        continue
    assert not np.isnan(arr).any(), f"{name} contains NaN values"
    assert not np.isinf(arr).any(), f"{name} contains Inf values"
    print(f"{name}: shape={arr.shape}, min={arr.min():.3f}, max={arr.max():.3f}, mean={arr.mean():.3f}")

print("\nInput tensor shape matches Flutter model input (64, 216, 1): OK")

# Class balance across splits
print("\nTrain label distribution:")
print(pd.Series(y_train).map(INVERSE_LABEL_MAP).value_counts().reindex(ALL_CLASSES))

print("\nValidation label distribution:")
print(pd.Series(y_val).map(INVERSE_LABEL_MAP).value_counts().reindex(ALL_CLASSES))

if len(y_real_test) > 0:
    print("\nReal-mic label distribution:")
    print(pd.Series(y_real_test).map(INVERSE_LABEL_MAP).value_counts())

# Visual check of one processed spectrogram
sample_idx = 0
plt.figure(figsize=(8, 4))
plt.imshow(X_train[sample_idx, :, :, 0], aspect="auto", origin="lower")
plt.title(f"Sample training spectrogram — label: {INVERSE_LABEL_MAP[y_train[sample_idx]]}")
plt.xlabel("Time frames")
plt.ylabel("Mel bands")
plt.colorbar()
plt.tight_layout()
plt.show()
# Out:
# X_train: shape=(2880, 64, 216, 1), min=-6.447, max=7.381, mean=-0.083
# X_val: shape=(48, 64, 216, 1), min=-3.556, max=10.311, mean=0.000
# X_real_test: shape=(30, 64, 216, 1), min=-4.662, max=4.057, mean=-0.000
#
# Input tensor shape matches Flutter model input (64, 216, 1): OK
#
# Train label distribution:
# siren              480
# crying_baby        480
# door_wood_knock    480
# glass_breaking     480
# fireworks          480
# car_horn           480
# Name: count, dtype: int64
#
# Validation label distribution:
# siren              8
# crying_baby        8
# door_wood_knock    8
# glass_breaking     8
# fireworks          8
# car_horn           8
# Name: count, dtype: int64
#
# Real-mic label distribution:
# siren              5
# crying_baby        5
# door_wood_knock    5
# glass_breaking     5
# fireworks          5
# car_horn           5
# Name: count, dtype: int64

# %% [markdown]
# ## SECTION 10 — Build CNN
#
# Same architecture as before. The only functional change is the output layer size: `len(ALL_CLASSES)` instead of `len(EMERGENCY_CLASSES)`, since the model now has more classes to separate.

# %%
model = models.Sequential([

    layers.Input(shape=(N_MELS, MAX_PAD_LEN, 1)),

    # Block 1
    layers.Conv2D(32, (3, 3), padding="same", kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3, 3), padding="same", kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.30),

    # Block 3
    layers.Conv2D(128, (3, 3), padding="same", kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.35),

    layers.GlobalAveragePooling2D(),

    layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.50),

    layers.Dense(NUM_CLASSES, activation="softmax"),
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 216, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 216, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64, 216, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 108, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 108, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 108, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 108, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 108, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 54, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 54, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 54, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 27, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 27, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 110,854 (433.02 KB)
#  Trainable params: 110,406 (431.27 KB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ## SECTION 11 — Train

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-4)

model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=12,
    restore_best_weights=True,
    verbose=1,
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=4,
    min_lr=1e-6,
    verbose=1,
)

checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1,
)

print("\nTraining...")

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=80,
    batch_size=16,
    shuffle=True,
    callbacks=[early_stopping, reduce_lr, checkpoint],
)

# Load the best saved model
model = tf.keras.models.load_model("best_model.keras")
# Out:
# Training...
# Epoch 1/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.2861 - loss: 1.7386
# Epoch 1: val_accuracy improved from -inf to 0.16667, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 196ms/step - accuracy: 0.2866 - loss: 1.7372 - val_accuracy: 0.1667 - val_loss: 2.3448 - learning_rate: 5.0000e-04
# Epoch 2/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.5198 - loss: 1.1926
# Epoch 2: val_accuracy improved from 0.16667 to 0.35417, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 34s 191ms/step - accuracy: 0.5200 - loss: 1.1923 - val_accuracy: 0.3542 - val_loss: 1.4893 - learning_rate: 5.0000e-04
# Epoch 3/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6037 - loss: 1.0245
# Epoch 3: val_accuracy improved from 0.35417 to 0.54167, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 34s 188ms/step - accuracy: 0.6038 - loss: 1.0243 - val_accuracy: 0.5417 - val_loss: 1.0839 - learning_rate: 5.0000e-04
# Epoch 4/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6636 - loss: 0.9008
# Epoch 4: val_accuracy improved from 0.54167 to 0.68750, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 192ms/step - accuracy: 0.6636 - loss: 0.9007 - val_accuracy: 0.6875 - val_loss: 0.8516 - learning_rate: 5.0000e-04
# Epoch 5/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7039 - loss: 0.8127
# Epoch 5: val_accuracy did not improve from 0.68750
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 193ms/step - accuracy: 0.7040 - loss: 0.8126 - val_accuracy: 0.6667 - val_loss: 0.8284 - learning_rate: 5.0000e-04
# Epoch 6/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7286 - loss: 0.7512
# Epoch 6: val_accuracy did not improve from 0.68750
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.7286 - loss: 0.7511 - val_accuracy: 0.6458 - val_loss: 0.8254 - learning_rate: 5.0000e-04
# Epoch 7/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7557 - loss: 0.6881
# Epoch 7: val_accuracy improved from 0.68750 to 0.72917, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.7558 - loss: 0.6880 - val_accuracy: 0.7292 - val_loss: 0.6397 - learning_rate: 5.0000e-04
# Epoch 8/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7739 - loss: 0.6353
# Epoch 8: val_accuracy did not improve from 0.72917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 33s 181ms/step - accuracy: 0.7739 - loss: 0.6353 - val_accuracy: 0.6667 - val_loss: 0.7486 - learning_rate: 5.0000e-04
# Epoch 9/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7881 - loss: 0.6110
# Epoch 9: val_accuracy did not improve from 0.72917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 34s 188ms/step - accuracy: 0.7882 - loss: 0.6108 - val_accuracy: 0.7292 - val_loss: 0.5410 - learning_rate: 5.0000e-04
# Epoch 10/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8040 - loss: 0.5555
# Epoch 10: val_accuracy improved from 0.72917 to 0.83333, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8040 - loss: 0.5554 - val_accuracy: 0.8333 - val_loss: 0.3869 - learning_rate: 5.0000e-04
# Epoch 11/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8264 - loss: 0.5078
# Epoch 11: val_accuracy did not improve from 0.83333
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 34s 189ms/step - accuracy: 0.8263 - loss: 0.5079 - val_accuracy: 0.7708 - val_loss: 0.5205 - learning_rate: 5.0000e-04
# Epoch 12/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8343 - loss: 0.5025
# Epoch 12: val_accuracy did not improve from 0.83333
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8343 - loss: 0.5024 - val_accuracy: 0.8333 - val_loss: 0.4776 - learning_rate: 5.0000e-04
# Epoch 13/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8387 - loss: 0.4617
# Epoch 13: val_accuracy did not improve from 0.83333
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.8387 - loss: 0.4617 - val_accuracy: 0.7708 - val_loss: 0.4616 - learning_rate: 5.0000e-04
# Epoch 14/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8511 - loss: 0.4565
# Epoch 14: val_accuracy improved from 0.83333 to 0.91667, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 34s 190ms/step - accuracy: 0.8511 - loss: 0.4564 - val_accuracy: 0.9167 - val_loss: 0.2880 - learning_rate: 5.0000e-04
# Epoch 15/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8591 - loss: 0.4165
# Epoch 15: val_accuracy did not improve from 0.91667
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 193ms/step - accuracy: 0.8591 - loss: 0.4166 - val_accuracy: 0.9167 - val_loss: 0.3734 - learning_rate: 5.0000e-04
# Epoch 16/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8708 - loss: 0.3987
# Epoch 16: val_accuracy did not improve from 0.91667
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 34s 189ms/step - accuracy: 0.8708 - loss: 0.3987 - val_accuracy: 0.8125 - val_loss: 0.4926 - learning_rate: 5.0000e-04
# Epoch 17/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8725 - loss: 0.4033
# Epoch 17: val_accuracy did not improve from 0.91667
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8725 - loss: 0.4034 - val_accuracy: 0.8333 - val_loss: 0.3943 - learning_rate: 5.0000e-04
# Epoch 18/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8890 - loss: 0.3725
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 18: val_accuracy did not improve from 0.91667
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8890 - loss: 0.3725 - val_accuracy: 0.8958 - val_loss: 0.3421 - learning_rate: 5.0000e-04
# Epoch 19/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8838 - loss: 0.3601
# Epoch 19: val_accuracy improved from 0.91667 to 0.97917, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.8839 - loss: 0.3601 - val_accuracy: 0.9792 - val_loss: 0.2060 - learning_rate: 2.5000e-04
# Epoch 20/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9021 - loss: 0.3355
# Epoch 20: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 197ms/step - accuracy: 0.9021 - loss: 0.3355 - val_accuracy: 0.9583 - val_loss: 0.1385 - learning_rate: 2.5000e-04
# Epoch 21/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9012 - loss: 0.3150
# Epoch 21: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9011 - loss: 0.3150 - val_accuracy: 0.9375 - val_loss: 0.3027 - learning_rate: 2.5000e-04
# Epoch 22/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9019 - loss: 0.3137
# Epoch 22: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 195ms/step - accuracy: 0.9019 - loss: 0.3137 - val_accuracy: 0.9792 - val_loss: 0.1739 - learning_rate: 2.5000e-04
# Epoch 23/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9148 - loss: 0.2925
# Epoch 23: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9148 - loss: 0.2925 - val_accuracy: 0.9583 - val_loss: 0.2231 - learning_rate: 2.5000e-04
# Epoch 24/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8931 - loss: 0.3103
# Epoch 24: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.8931 - loss: 0.3103 - val_accuracy: 0.9583 - val_loss: 0.1378 - learning_rate: 2.5000e-04
# Epoch 25/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9184 - loss: 0.2807
# Epoch 25: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9184 - loss: 0.2807 - val_accuracy: 0.9583 - val_loss: 0.1599 - learning_rate: 2.5000e-04
# Epoch 26/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9027 - loss: 0.3006
# Epoch 26: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 197ms/step - accuracy: 0.9027 - loss: 0.3006 - val_accuracy: 0.9583 - val_loss: 0.2033 - learning_rate: 2.5000e-04
# Epoch 27/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9125 - loss: 0.2793
# Epoch 27: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9125 - loss: 0.2794 - val_accuracy: 0.9583 - val_loss: 0.2017 - learning_rate: 2.5000e-04
# Epoch 28/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9158 - loss: 0.2860
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 28: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9158 - loss: 0.2860 - val_accuracy: 0.9792 - val_loss: 0.1891 - learning_rate: 2.5000e-04
# Epoch 29/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9237 - loss: 0.2553
# Epoch 29: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9237 - loss: 0.2553 - val_accuracy: 0.9792 - val_loss: 0.1087 - learning_rate: 1.2500e-04
# Epoch 30/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9221 - loss: 0.2499
# Epoch 30: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9221 - loss: 0.2499 - val_accuracy: 0.9583 - val_loss: 0.1101 - learning_rate: 1.2500e-04
# Epoch 31/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9341 - loss: 0.2580
# Epoch 31: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9341 - loss: 0.2580 - val_accuracy: 0.9583 - val_loss: 0.1549 - learning_rate: 1.2500e-04
# Epoch 32/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9279 - loss: 0.2394
# Epoch 32: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9279 - loss: 0.2394 - val_accuracy: 0.9792 - val_loss: 0.1255 - learning_rate: 1.2500e-04
# Epoch 33/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9323 - loss: 0.2287
# Epoch 33: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 34s 191ms/step - accuracy: 0.9323 - loss: 0.2287 - val_accuracy: 0.9792 - val_loss: 0.0800 - learning_rate: 1.2500e-04
# Epoch 34/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9288 - loss: 0.2414
# Epoch 34: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9289 - loss: 0.2413 - val_accuracy: 0.9583 - val_loss: 0.1054 - learning_rate: 1.2500e-04
# Epoch 35/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9245 - loss: 0.2386
# Epoch 35: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 196ms/step - accuracy: 0.9245 - loss: 0.2386 - val_accuracy: 0.9792 - val_loss: 0.1118 - learning_rate: 1.2500e-04
# Epoch 36/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9400 - loss: 0.2205
# Epoch 36: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9400 - loss: 0.2205 - val_accuracy: 0.9583 - val_loss: 0.1255 - learning_rate: 1.2500e-04
# Epoch 37/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9307 - loss: 0.2288
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 37: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9307 - loss: 0.2288 - val_accuracy: 0.9792 - val_loss: 0.1250 - learning_rate: 1.2500e-04
# Epoch 38/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9400 - loss: 0.2181
# Epoch 38: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9399 - loss: 0.2181 - val_accuracy: 0.9792 - val_loss: 0.0738 - learning_rate: 6.2500e-05
# Epoch 39/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9358 - loss: 0.2217
# Epoch 39: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9358 - loss: 0.2216 - val_accuracy: 0.9792 - val_loss: 0.0831 - learning_rate: 6.2500e-05
# Epoch 40/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9394 - loss: 0.2124
# Epoch 40: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9394 - loss: 0.2123 - val_accuracy: 0.9792 - val_loss: 0.0834 - learning_rate: 6.2500e-05
# Epoch 41/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9404 - loss: 0.2112
# Epoch 41: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 194ms/step - accuracy: 0.9405 - loss: 0.2112 - val_accuracy: 0.9792 - val_loss: 0.0878 - learning_rate: 6.2500e-05
# Epoch 42/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9406 - loss: 0.2098
# Epoch 42: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9406 - loss: 0.2098 - val_accuracy: 0.9792 - val_loss: 0.0725 - learning_rate: 6.2500e-05
# Epoch 43/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9549 - loss: 0.1952
# Epoch 43: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9548 - loss: 0.1952 - val_accuracy: 0.9792 - val_loss: 0.0872 - learning_rate: 6.2500e-05
# Epoch 44/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9498 - loss: 0.2012
# Epoch 44: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 199ms/step - accuracy: 0.9498 - loss: 0.2012 - val_accuracy: 0.9792 - val_loss: 0.0863 - learning_rate: 6.2500e-05
# Epoch 45/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9445 - loss: 0.2054
# Epoch 45: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9445 - loss: 0.2054 - val_accuracy: 0.9792 - val_loss: 0.0822 - learning_rate: 6.2500e-05
# Epoch 46/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9397 - loss: 0.2108
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 46: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9397 - loss: 0.2108 - val_accuracy: 0.9792 - val_loss: 0.0726 - learning_rate: 6.2500e-05
# Epoch 47/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9404 - loss: 0.2067
# Epoch 47: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9405 - loss: 0.2066 - val_accuracy: 0.9792 - val_loss: 0.0710 - learning_rate: 3.1250e-05
# Epoch 48/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9450 - loss: 0.1923
# Epoch 48: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 198ms/step - accuracy: 0.9450 - loss: 0.1923 - val_accuracy: 0.9792 - val_loss: 0.0614 - learning_rate: 3.1250e-05
# Epoch 49/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9465 - loss: 0.1946
# Epoch 49: val_accuracy did not improve from 0.97917
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9465 - loss: 0.1947 - val_accuracy: 0.9792 - val_loss: 0.0714 - learning_rate: 3.1250e-05
# Epoch 50/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9467 - loss: 0.1937
# Epoch 50: val_accuracy improved from 0.97917 to 1.00000, saving model to best_model.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9467 - loss: 0.1937 - val_accuracy: 1.0000 - val_loss: 0.0579 - learning_rate: 3.1250e-05
# Epoch 51/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9418 - loss: 0.1981
# Epoch 51: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 33s 184ms/step - accuracy: 0.9418 - loss: 0.1981 - val_accuracy: 0.9792 - val_loss: 0.0604 - learning_rate: 3.1250e-05
# Epoch 52/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9455 - loss: 0.1976
# Epoch 52: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 33s 184ms/step - accuracy: 0.9455 - loss: 0.1976 - val_accuracy: 0.9792 - val_loss: 0.0596 - learning_rate: 3.1250e-05
# Epoch 53/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9437 - loss: 0.1959
# Epoch 53: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 31s 175ms/step - accuracy: 0.9437 - loss: 0.1958 - val_accuracy: 0.9792 - val_loss: 0.0771 - learning_rate: 3.1250e-05
# Epoch 54/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9414 - loss: 0.1999
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 54: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 31s 172ms/step - accuracy: 0.9414 - loss: 0.1999 - val_accuracy: 0.9792 - val_loss: 0.0640 - learning_rate: 3.1250e-05
# Epoch 55/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9543 - loss: 0.1903
# Epoch 55: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 32s 175ms/step - accuracy: 0.9543 - loss: 0.1903 - val_accuracy: 0.9792 - val_loss: 0.0620 - learning_rate: 1.5625e-05
# Epoch 56/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9512 - loss: 0.1983
# Epoch 56: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 31s 174ms/step - accuracy: 0.9512 - loss: 0.1982 - val_accuracy: 0.9792 - val_loss: 0.0647 - learning_rate: 1.5625e-05
# Epoch 57/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9521 - loss: 0.1933
# Epoch 57: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 31s 171ms/step - accuracy: 0.9520 - loss: 0.1933 - val_accuracy: 0.9792 - val_loss: 0.0612 - learning_rate: 1.5625e-05
# Epoch 58/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9514 - loss: 0.1928
# Epoch 58: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 58: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 31s 170ms/step - accuracy: 0.9514 - loss: 0.1928 - val_accuracy: 0.9792 - val_loss: 0.0598 - learning_rate: 1.5625e-05
# Epoch 59/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9483 - loss: 0.1893
# Epoch 59: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 29s 163ms/step - accuracy: 0.9484 - loss: 0.1892 - val_accuracy: 0.9792 - val_loss: 0.0638 - learning_rate: 7.8125e-06
# Epoch 60/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9501 - loss: 0.1883
# Epoch 60: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 30s 164ms/step - accuracy: 0.9501 - loss: 0.1882 - val_accuracy: 0.9792 - val_loss: 0.0639 - learning_rate: 7.8125e-06
# Epoch 61/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9429 - loss: 0.1962
# Epoch 61: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - accuracy: 0.9430 - loss: 0.1962 - val_accuracy: 0.9792 - val_loss: 0.0606 - learning_rate: 7.8125e-06
# Epoch 62/80
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9434 - loss: 0.2045
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 62: val_accuracy did not improve from 1.00000
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9434 - loss: 0.2044 - val_accuracy: 0.9792 - val_loss: 0.0619 - learning_rate: 7.8125e-06
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 50.

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Train")
plt.plot(history.history["val_accuracy"], label="Validation")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Validation")
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## SECTION 12 — Evaluation (ESC-50 Validation Set)
#
# Three views are reported:
# 1. **Full multi-class report** across all `ALL_CLASSES` — this is what the model actually outputs.
# 2. **Emergency vs. non-emergency rollup** — collapses the 16 classes into a binary "is this an emergency?" decision. This tells you how often a negative-class sound gets pulled into *any* emergency label, regardless of which one.
# 3. **Leak report** — a full confusion matrix is hard to read once you have 16 classes. This zooms in on just the `EMERGENCY_CLASSES` and shows, in plain terms, (a) when an emergency clip is missed, what it gets predicted as instead (*recall leak* — who is stealing its recall), and (b) when the model predicts an emergency class, what the clip actually was when it's wrong (*precision leak* — what's contaminating that prediction, i.e. a direct false-alarm source).

# %%
y_val_pred = np.argmax(model.predict(X_val), axis=1)

print("=" * 60)
print("VALIDATION SET PERFORMANCE (ESC-50, all classes)")
print("=" * 60)
print(classification_report(y_val, y_val_pred, target_names=ALL_CLASSES, zero_division=0))
print("Confusion Matrix (rows=true, cols=pred), order = ALL_CLASSES:")
print(confusion_matrix(y_val, y_val_pred, labels=list(range(NUM_CLASSES))))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ============================================================
# VALIDATION SET PERFORMANCE (ESC-50, all classes)
# ============================================================
#                  precision    recall  f1-score   support
#
#           siren       1.00      1.00      1.00         8
#     crying_baby       1.00      1.00      1.00         8
# door_wood_knock       1.00      1.00      1.00         8
#  glass_breaking       1.00      1.00      1.00         8
#       fireworks       1.00      1.00      1.00         8
#        car_horn       1.00      1.00      1.00         8
#
#        accuracy                           1.00        48
#       macro avg       1.00      1.00      1.00        48
#    weighted avg       1.00      1.00      1.00        48
#
# Confusion Matrix (rows=true, cols=pred), order = ALL_CLASSES:
# [[8 0 0 0 0 0]
#  [0 8 0 0 0 0]
#  [0 0 8 0 0 0]
#  [0 0 0 8 0 0]
#  [0 0 0 0 8 0]
#  [0 0 0 0 0 8]]

# %%
def to_binary_emergency(labels):
    return np.array([1 if l in EMERGENCY_LABEL_IDS else 0 for l in labels])

if INCLUDE_NEGATIVE_CLASSES:
    y_val_binary_true = to_binary_emergency(y_val)
    y_val_binary_pred = to_binary_emergency(y_val_pred)

    print("\n" + "=" * 60)
    print("VALIDATION SET — EMERGENCY vs NON-EMERGENCY ROLLUP")
    print("=" * 60)
    print(classification_report(
        y_val_binary_true, y_val_binary_pred,
        target_names=["non_emergency", "emergency"],
        zero_division=0,
    ))
    print("Confusion Matrix ([non_emergency, emergency]):")
    print(confusion_matrix(y_val_binary_true, y_val_binary_pred))
else:
    print("Skipping emergency vs non-emergency rollup — no negative classes in this run "
          "(every class is an emergency class right now, so the rollup would be trivial).")
# Out:
# Skipping emergency vs non-emergency rollup — no negative classes in this run (every class is an emergency class right now, so the rollup would be trivial).

# %%
def leak_report(y_true, y_pred, focus_classes,
                 label_map=LABEL_MAP,
                 inverse_label_map=INVERSE_LABEL_MAP,
                 emergency_ids=EMERGENCY_LABEL_IDS):
    """
    Zooms in on `focus_classes` only (instead of the full NxN confusion
    matrix) and reports two directions of leakage:

    RECALL LEAK  — for each focus class, when a true instance of it is
    missed, which class does it get predicted as instead? Answers:
    "who is stealing this class's recall?"

    PRECISION LEAK — for each focus class, when the model predicts it,
    what was the clip actually? Answers: "when this class fires, what's
    contaminating it?" — i.e. the direct source of false alarms.
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)

    print("--- RECALL LEAK: where do true instances end up when misclassified? ---")
    for cls in focus_classes:
        cls_id = label_map[cls]
        mask = y_true == cls_id
        n = int(mask.sum())
        if n == 0:
            print(f"\n{cls}: no ground-truth samples in this set, skipping")
            continue

        preds_for_class = y_pred[mask]
        correct = int((preds_for_class == cls_id).sum())
        print(f"\n{cls} (n={n}) — correct: {correct}/{n} ({100 * correct / n:.0f}%)")

        wrong = preds_for_class[preds_for_class != cls_id]
        if len(wrong) == 0:
            continue
        wrong_counts = pd.Series(wrong).map(inverse_label_map).value_counts()
        for name, count in wrong_counts.items():
            tag = "EMERGENCY" if label_map[name] in emergency_ids else "negative"
            print(f"    -> leaked to {name:20s} ({tag:9s}): {count} ({100 * count / n:.0f}%)")

    print("\n--- PRECISION LEAK: when this class is predicted, what's actually contaminating it? ---")
    for cls in focus_classes:
        cls_id = label_map[cls]
        mask = y_pred == cls_id
        n = int(mask.sum())
        if n == 0:
            print(f"\npredicted {cls}: model never predicted this class in this set")
            continue

        true_for_pred = y_true[mask]
        correct = int((true_for_pred == cls_id).sum())
        print(f"\npredicted {cls} (n={n}) — actually correct: {correct}/{n} ({100 * correct / n:.0f}%)")

        wrong = true_for_pred[true_for_pred != cls_id]
        if len(wrong) == 0:
            continue
        wrong_counts = pd.Series(wrong).map(inverse_label_map).value_counts()
        for name, count in wrong_counts.items():
            tag = "EMERGENCY" if label_map[name] in emergency_ids else "negative"
            print(f"    <- actually was {name:20s} ({tag:9s}): {count} ({100 * count / n:.0f}%)")


print("=" * 60)
print("VALIDATION SET — LEAK REPORT (EMERGENCY_CLASSES)")
print("=" * 60)
leak_report(y_val, y_val_pred, focus_classes=EMERGENCY_CLASSES)
# Out:
# ============================================================
# VALIDATION SET — LEAK REPORT (EMERGENCY_CLASSES)
# ============================================================
# --- RECALL LEAK: where do true instances end up when misclassified? ---
#
# siren (n=8) — correct: 8/8 (100%)
#
# crying_baby (n=8) — correct: 8/8 (100%)
#
# door_wood_knock (n=8) — correct: 8/8 (100%)
#
# glass_breaking (n=8) — correct: 8/8 (100%)
#
# fireworks (n=8) — correct: 8/8 (100%)
#
# car_horn (n=8) — correct: 8/8 (100%)
#
# --- PRECISION LEAK: when this class is predicted, what's actually contaminating it? ---
#
# predicted siren (n=8) — actually correct: 8/8 (100%)
#
# predicted crying_baby (n=8) — actually correct: 8/8 (100%)
#
# predicted door_wood_knock (n=8) — actually correct: 8/8 (100%)
#
# predicted glass_breaking (n=8) — actually correct: 8/8 (100%)
#
# predicted fireworks (n=8) — actually correct: 8/8 (100%)
#
# predicted car_horn (n=8) — actually correct: 8/8 (100%)

# %% [markdown]
# ## SECTION 13 — Real Microphone Evaluation
#
# Evaluated only on the classes actually present in `REAL_MIC_DIR` (typically just the emergency classes, unless you've also collected real-mic negative-class recordings). This set is never touched during training or validation.
#
# Includes the same leak report as Section 12 — this is the more important of the two, since it's the one that reflects real deployment conditions rather than clean ESC-50 studio audio.

# %%
if len(y_real_test) > 0:
    y_real_pred = np.argmax(model.predict(X_real_test), axis=1)

    present_label_ids = sorted(set(y_real_test) | set(y_real_pred))
    present_class_names = [INVERSE_LABEL_MAP[i] for i in present_label_ids]

    print("=" * 60)
    print("REAL-WORLD TEST PERFORMANCE (Phone Microphone Recordings)")
    print("=" * 60)
    print(f"(n={len(y_real_test)})")
    print(classification_report(
        y_real_test, y_real_pred,
        labels=present_label_ids,
        target_names=present_class_names,
        zero_division=0,
    ))
    print("Confusion Matrix:")
    print(confusion_matrix(y_real_test, y_real_pred, labels=present_label_ids))

    # Binary rollup on real-mic data too, since this is the number that
    # matters most for the deployed app's false-positive rate. Only
    # meaningful once negative classes are back in the mix.
    if INCLUDE_NEGATIVE_CLASSES:
        y_real_binary_true = to_binary_emergency(y_real_test)
        y_real_binary_pred = to_binary_emergency(y_real_pred)

        print("\n" + "=" * 60)
        print("REAL-WORLD TEST — EMERGENCY vs NON-EMERGENCY ROLLUP")
        print("=" * 60)
        print(classification_report(
            y_real_binary_true, y_real_binary_pred,
            target_names=["non_emergency", "emergency"],
            zero_division=0,
        ))
        print("Confusion Matrix ([non_emergency, emergency]):")
        print(confusion_matrix(y_real_binary_true, y_real_binary_pred))
    else:
        print("\nSkipping emergency vs non-emergency rollup — no negative classes in this run.")

    print("\n" + "=" * 60)
    print("REAL-WORLD TEST — LEAK REPORT (EMERGENCY_CLASSES)")
    print("=" * 60)
    leak_report(y_real_test, y_real_pred, focus_classes=EMERGENCY_CLASSES)
else:
    print("No real-world microphone clips loaded — skipping real-mic evaluation.")
    print("(REAL_MIC_DIR must never be used for training/validation, only here.)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# ============================================================
# REAL-WORLD TEST PERFORMANCE (Phone Microphone Recordings)
# ============================================================
# (n=30)
#                  precision    recall  f1-score   support
#
#           siren       1.00      0.80      0.89         5
#     crying_baby       1.00      1.00      1.00         5
# door_wood_knock       1.00      1.00      1.00         5
#  glass_breaking       0.56      1.00      0.71         5
#       fireworks       1.00      0.40      0.57         5
#        car_horn       1.00      1.00      1.00         5
#
#        accuracy                           0.87        30
#       macro avg       0.93      0.87      0.86        30
#    weighted avg       0.93      0.87      0.86        30
#
# Confusion Matrix:
# [[4 0 0 1 0 0]
#  [0 5 0 0 0 0]
#  [0 0 5 0 0 0]
#  [0 0 0 5 0 0]
#  [0 0 0 3 2 0]
#  [0 0 0 0 0 5]]
#
# Skipping emergency vs non-emergency rollup — no negative classes in this run.
#
# ============================================================
# REAL-WORLD TEST — LEAK REPORT (EMERGENCY_CLASSES)
# ============================================================
# --- RECALL LEAK: where do true instances end up when misclassified? ---
#
# siren (n=5) — correct: 4/5 (80%)
#     -> leaked to glass_breaking       (EMERGENCY): 1 (20%)
#
# crying_baby (n=5) — correct: 5/5 (100%)
#
# door_wood_knock (n=5) — correct: 5/5 (100%)
#
# glass_breaking (n=5) — correct: 5/5 (100%)
#
# fireworks (n=5) — correct: 2/5 (40%)
#     -> leaked to glass_breaking       (EMERGENCY): 3 (60%)
#
# car_horn (n=5) — correct: 5/5 (100%)
#
# --- PRECISION LEAK: when this class is predicted, what's actually contaminating it? ---
#
# predicted siren (n=4) — actually correct: 4/4 (100%)
#
# predicted crying_baby (n=5) — actually correct: 5/5 (100%)
#
# predicted door_wood_knock (n=5) — actually correct: 5/5 (100%)
#
# predicted glass_breaking (n=9) — actually correct: 5/9 (56%)
#     <- actually was fireworks            (EMERGENCY): 3 (33%)
#     <- actually was siren                (EMERGENCY): 1 (11%)
#
# predicted fireworks (n=2) — actually correct: 2/2 (100%)
#
# predicted car_horn (n=5) — actually correct: 5/5 (100%)

# %% [markdown]
# ## SECTION 14 — Export TensorFlow Lite
#
# `labels.txt` is written in `ALL_CLASSES` order, which matches the model's output layer exactly. **This is a breaking change for the Flutter app**: the output size grows from 6 to 16 classes, so the app's label list and any index-based logic need to be updated to match `labels.txt` before this model is deployed.

# %%
print("Exporting to TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open("emergency_audio_classifier.tflite", "wb") as f:
    f.write(tflite_model)

with open("labels.txt", "w") as f:
    for category in ALL_CLASSES:
        f.write(f"{category}\n")

print("Saved: emergency_audio_classifier.tflite")
print("Saved: labels.txt")
print(f"\nModel outputs {NUM_CLASSES} classes in this order:")
for idx, category in enumerate(ALL_CLASSES):
    tag = "EMERGENCY" if idx in EMERGENCY_LABEL_IDS else "negative"
    print(f"  {idx}: {category} ({tag})")
# Out:
# Exporting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\ACER\AppData\Local\Temp\tmp3f05rlig\assets
# INFO:tensorflow:Assets written to: C:\Users\ACER\AppData\Local\Temp\tmp3f05rlig\assets
# Saved artifact at 'C:\Users\ACER\AppData\Local\Temp\tmp3f05rlig'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 216, 1), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   1382125549520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382125551056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382125550480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382125549904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382125549328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382125550672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381963001936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962997328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962996176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381963002512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962996368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381963002128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962997520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962999248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962998480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381963002896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962999056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1381962999824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382130910032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382130913104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382130914448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1382130915984: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved: emergency_audio_classifier.tflite
# Saved: labels.txt
#
# Model outputs 6 classes in this order:
#   0: siren (EMERGENCY)
#   1: crying_baby (EMERGENCY)
#   2: door_wood_knock (EMERGENCY)
#   3: glass_breaking (EMERGENCY)
#   4: fireworks (EMERGENCY)
#   5: car_horn (EMERGENCY)
